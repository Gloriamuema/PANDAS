# %%
import http.client
import json
import pandas as pd 


conn = http.client.HTTPSConnection("api.collectapi.com")

headers = {
    'content-type': "application/json",
    'authorization': "apikey 58mZ1nq40hESqQKgspMMGG:1TVmfC219hl24aPkk6ntlv"
    }

conn.request("GET", "/gasPrice/allUsaPrice", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"success":true,"result":[{"currency":"usd","name":"Alaska","gasoline":"3.754","midGrade":"3.968","premium":"4.205","diesel":"4.062"},{"currency":"usd","name":"Alabama","gasoline":"2.788","midGrade":"3.240","premium":"3.639","diesel":"3.481"},{"currency":"usd","name":"Arkansas","gasoline":"2.787","midGrade":"3.237","premium":"3.609","diesel":"3.407"},{"currency":"usd","name":"Arizona","gasoline":"3.202","midGrade":"3.557","premium":"3.879","diesel":"3.649"},{"currency":"usd","name":"California","gasoline":"4.481","midGrade":"4.711","premium":"4.891","diesel":"5.179"},{"currency":"usd","name":"Colorado","gasoline":"2.986","midGrade":"3.376","premium":"3.700","diesel":"3.500"},{"currency":"usd","name":"Connecticut","gasoline":"3.107","midGrade":"3.700","premium":"4.066","diesel":"3.794"},{"currency":"usd","name":"District of Columbia","gasoline":"3.329","midGrade":"3.815","premium":"4.252","diesel":"3.848"},{"currency":"usd","name":"Delaware","gasoline":"3.099","midGrade":"3.669","premium":"3.958","diesel":"3.763"},{"currency":"usd","name":"Florida","gasoline":"3.005","midGrade":"3.455","premium":"3.773","diesel":"3.623"},{"currency":"usd","name":"Georgia","gasoline":"2.921","midGrade":"3.392","premium":"3.794","diesel":"3.606"},{"currency":"usd","name":"Hawaii","gasoline":"4.475","midGrade":"4.701","premium":"4.963","diesel":"5.230"},{"currency":"usd","name":"Iowa","gasoline":"2.999","midGrade":"3.205","premium":"3.780","diesel":"3.570"},{"currency":"usd","name":"Idaho","gasoline":"3.483","midGrade":"3.767","premium":"4.040","diesel":"3.963"},{"currency":"usd","name":"Illinois","gasoline":"3.443","midGrade":"4.036","premium":"4.494","diesel":"3.785"},{"currency":"usd","name":"Indiana","gasoline":"3.253","midGrade":"3.782","premium":"4.275","diesel":"3.860"},{"currency":"usd","name":"Kansas","gasoline":"2.851","midGrade":"3.182","premium":"3.526","diesel":"3.482"},{"currency":"usd","name":"Kentucky","gasoline":"2.869","midGrade":"3.418","premium":"3.835","diesel":"3.462"},{"currency":"usd","name":"Louisiana","gasoline":"2.777","midGrade":"3.225","premium":"3.597","diesel":"3.371"},{"currency":"usd","name":"Massachusetts","gasoline":"3.044","midGrade":"3.664","premium":"4.030","diesel":"3.847"},{"currency":"usd","name":"Maryland","gasoline":"3.106","midGrade":"3.696","premium":"4.000","diesel":"3.786"},{"currency":"usd","name":"Maine","gasoline":"3.095","midGrade":"3.655","premium":"4.108","diesel":"3.893"},{"currency":"usd","name":"Michigan","gasoline":"3.161","midGrade":"3.727","premium":"4.279","diesel":"3.732"},{"currency":"usd","name":"Minnesota","gasoline":"3.026","midGrade":"3.446","premium":"3.880","diesel":"3.624"},{"currency":"usd","name":"Missouri","gasoline":"2.846","midGrade":"3.209","premium":"3.529","diesel":"3.475"},{"currency":"usd","name":"Mississippi","gasoline":"2.711","midGrade":"3.168","premium":"3.527","diesel":"3.315"},{"currency":"usd","name":"Montana","gasoline":"3.246","midGrade":"3.556","premium":"3.893","diesel":"3.650"},{"currency":"usd","name":"North Carolina","gasoline":"2.900","midGrade":"3.360","premium":"3.743","diesel":"3.536"},{"currency":"usd","name":"North Dakota","gasoline":"2.911","midGrade":"3.250","premium":"3.589","diesel":"3.436"},{"currency":"usd","name":"Nebraska","gasoline":"2.951","midGrade":"3.158","premium":"3.651","diesel":"3.444"},{"currency":"usd","name":"New Hampshire","gasoline":"2.994","midGrade":"3.578","premium":"3.994","diesel":"3.812"},{"currency":"usd","name":"New Jersey","gasoline":"3.063","midGrade":"3.627","premium":"3.883","diesel":"3.717"},{"currency":"usd","name":"New Mexico","gasoline":"2.916","midGrade":"3.324","premium":"3.601","diesel":"3.542"},{"currency":"usd","name":"Nevada","gasoline":"3.736","midGrade":"4.040","premium":"4.309","diesel":"3.973"},{"currency":"usd","name":"New York","gasoline":"3.167","midGrade":"3.690","premium":"4.066","diesel":"3.921"},{"currency":"usd","name":"Ohio","gasoline":"2.988","midGrade":"3.526","premium":"4.038","diesel":"3.66 ...

# %%
#checking type of data we have
type(data)
# Out:
# bytes

# %%
converted_data = json.loads(data.decode("utf-8"))
type(converted_data)
# Out:
# dict

# %%
converted_data
# Out:
# {'success': True,
#  'result': [{'currency': 'usd',
#    'name': 'Alaska',
#    'gasoline': '3.754',
#    'midGrade': '3.968',
#    'premium': '4.205',
#    'diesel': '4.062'},
#   {'currency': 'usd',
#    'name': 'Alabama',
#    'gasoline': '2.788',
#    'midGrade': '3.240',
#    'premium': '3.639',
#    'diesel': '3.481'},
#   {'currency': 'usd',
#    'name': 'Arkansas',
#    'gasoline': '2.787',
#    'midGrade': '3.237',
#    'premium': '3.609',
#    'diesel': '3.407'},
#   {'currency': 'usd',
#    'name': 'Arizona',
#    'gasoline': '3.202',
#    'midGrade': '3.557',
#    'premium': '3.879',
#    'diesel': '3.649'},
#   {'currency': 'usd',
#    'name': 'California',
#    'gasoline': '4.481',
#    'midGrade': '4.711',
#    'premium': '4.891',
#    'diesel': '5.179'},
#   {'currency': 'usd',
#    'name': 'Colorado',
#    'gasoline': '2.986',
#    'midGrade': '3.376',
#    'premium': '3.700',
#    'diesel': '3.500'},
#   {'currency': 'usd',
#    'name': 'Connecticut',
#    'gasoline': '3.107',
#    'midGrade': '3.700',
#    'premium': '4.066',
#    'diesel': '3.794'},
#   {'currency': 'usd',
#    'name': 'District of Columbia',
#    'gasoline': '3.329',
#    'midGrade': '3.815',
#    'premium': '4.252',
#    'diesel': '3.848'},
#   {'currency': 'usd',
#    'name': 'Delaware',
#    'gasoline': '3.099',
#    'midGrade': '3.669',
#    'premium': '3.958',
#    'diesel': '3.763'},
#   {'currency': 'usd',
#    'name': 'Florida',
#    'gasoline': '3.005',
#    'midGrade': '3.455',
#    'premium': '3.773',
#    'diesel': '3.623'},
#   {'currency': 'usd',
#    'name': 'Georgia',
#    'gasoline': '2.921',
#    'midGrade': '3.392',
#    'premium': '3.794',
#    'diesel': '3.606'},
#   {'currency': 'usd',
#    'name': 'Hawaii',
#    'gasoline': '4.475',
#    'midGrade': '4.701',
#    'premium': '4.963',
#    'diesel': '5.230'},
#   {'currency': 'usd',
#    'name': 'Iowa',
#    'gasoline': '2.999',
#    'midGrade': '3.205',
#    'premium': '3.780',
#    'diesel': '3.570'},
#   {'currency': 'usd',
#    'name': 'Idaho',
#    'gasoline': '3.483',
#    'midGrade': '3.767',
#    'premium': '4.040',
#    'diesel': '3.963'},
#   {'currency': 'usd',
#    'name': 'Illinois',
#    'gasoline': '3.443',
#    'midGrade': '4.036',
#    'premium': '4.494',
#    'diesel': '3.785'},
#   {'currency': 'usd',
#    'name': 'Indiana',
#    'gasoline': '3.253',
#    'midGrade': '3.782',
#    'premium': '4.275',
#    'diesel': '3.860'},
#   {'currency': 'usd',
#    'name': 'Kansas',
#    'gasoline': '2.851',
#    'midGrade': '3.182',
#    'premium': '3.526',
#    'diesel': '3.482'},
#   {'currency': 'usd',
#    'name': 'Kentucky',
#    'gasoline': '2.869',
#    'midGrade': '3.418',
#    'premium': '3.835',
#    'diesel': '3.462'},
#   {'currency': 'usd',
#    'name': 'Louisiana',
#    'gasoline': '2.777',
#    'midGrade': '3.225',
#    'premium': '3.597',
#    'diesel': '3.371'},
#   {'currency': 'usd',
#    'name': 'Massachusetts',
#    'gasoline': '3.044',
#    'midGrade': '3.664',
#    'premium': '4.030',
#    'diesel': '3.847'},
#   {'currency': 'usd',
#    'name': 'Maryland',
#    'gasoline': '3.106',
#    'midGrade': '3.696',
#    'premium': '4.000',
#    'diesel': '3.786'},
#   {'currency': 'usd',
#    'name': 'Maine',
#    'gasoline': '3.095',
#    'midGrade': '3.655',
#    'premium': '4.108',
#    'diesel': '3.893'},
#   {'currency': 'usd',
#    'name': 'Michigan',
#    'gasoline': '3.161',
#    'midGrade': '3.727',
#    'premium': '4.279',
#    'diesel': '3.732'},
#   {'currency': 'usd',
#    'name': 'Minnesota',
#    'gasoline': '3.026',
#    'midGrade': '3.446',
#    'premium': '3.880',
#    'diesel': '3.624'},
#   {'currency': 'usd',
#    'name': 'Missouri',
#    'gasoline': '2.846',
#    'midGrade': '3.209',
#    'premium': '3.529',
#    'diesel': '3.475'},
#   {'currency': 'usd',
#    'name': 'Mississippi',
#    'gasoline': '2.711',
#    'midGrade': '3.168',
#    'premium': '3.527',
#    'diesel': '3.315'},
#   {'currency': 'usd',
#    'name': 'Montana',
#    'gasoline': '3.246',
#    'midGrade': '3.556',
#    'premium': '3.893',
#    'diesel': '3.650'},
#   {'currency': 'usd',
#    'name': 'North Carolina',
#    'gasoline': '2.900',
#    'midGrade': '3.360',
#    'premium': '3.743',
#    'diesel': '3.536'},
#   {'currency': 'usd',
#    'name': 'North Dakota',
#    'gasoline': '2.911',
#    'midGrade': '3.250',
#    'premium': '3.589',
#    'diesel': '3.436'},
#   {'currency': 'usd',
#    'name': 'Nebraska',
#    'gasoline': '2.951',
#    'midGrade': '3.158',
#    'premium': '3.651',
#    'diesel': '3.444'},
#   {'currency': 'usd',
#    'name': 'New Hampshire',
#    'gasoline': '2.994',
#    'midGrade': '3.578',
#    'premium': '3.994',
#    'diesel': '3.812'},
#   {'currency': 'usd',
#    'name': 'New Jersey',
#    'gasoline': '3.063',
#    'midGrade': '3.627',
#    'premium': '3.883',
#    'diesel': '3.717'},
#   {'currency': 'usd',
#    'name': 'New Mexico',
#    'gasoline': '2.916',
#    'midGrade': '3.324',
#    'premium': '3.601',
#    'diesel': '3.542'},
#   {'currency': 'usd',
#    'name': 'Nevada',
#    'gasoline': '3.736',
#    'midGrade': '4.040',
#    'premium': '4.309',
#    'diesel': '3.973'},
#   {'currency': 'usd',
#    'name': 'New York',
#    'gasoline': '3.167',
#    'midGrade': '3.690',
#    'premium': '4.066',
#    'diesel': '3.921'},
#   {'currency': 'usd',
#    'name': 'Ohio',
#    'gasoline': '2.988',
#    'midGrade': '3.526',
#    'premium': '4.038',
#    'diesel': '3.669'},
#   {'currency': 'usd',
#    'name': 'Oklahoma',
#    'gasoline': '2.778',
#    'midGrade': '3.171',
#    'premium': '3.461',
#    'diesel': '3.343'},
#   {'currency': 'usd',
#    'name': 'Oregon',
#    'gasoline': '3.975',
#    'midGrade': '4.200',
#    'premium': '4.468',
#    'diesel': '4.502'},
#   {'currency': 'usd',
#    'name': 'Pennsylvania',
#    'gasoline': '3.236',
#    'midGrade': '3.685',
#    'premium': '4.049',
#    'diesel': '4.021'},
#   {'currency': 'usd',
#    'name': 'Rhode Island',
#    'gasoline': '3.021',
#    'midGrade': '3.753',
#    'premium': '4.150',
#    'diesel': '3.821'},
#   {'currency': 'usd',
#    'name': 'South Carolina',
#    'gasoline': '2.832',
#    'midGrade': '3.296',
#    'premium': '3.667',
#    'diesel': '3.494'},
#   {'currency': 'usd',
#    'name': 'South Dakota',
#    'gasoline': '3.033',
#    'midGrade': '3.189',
#    'premium': '3.673',
#    'diesel': '3.381'},
#   {'currency': 'usd',
#    'name': 'Tennessee',
#    'gasoline': '2.763',
#    'midGrade': '3.229',
#    'premium': '3.625',
#    'diesel': '3.455'},
#   {'currency': 'usd',
#    'name': 'Texas',
#    'gasoline': '2.779',
#    'midGrade': '3.257',
#    'premium': '3.609',
#    'diesel': '3.295'},
#   {'currency': 'usd',
#    'name': 'Utah',
#    'gasoline': '3.383',
#    'midGrade': '3.651',
#    'premium': '3.884',
#    'diesel': '3.737'},
#   {'currency': 'usd',
#    'name': 'Virginia',
#    'gasoline': '3.024',
#    'midGrade': '3.516',
#    'premium': '3.883',
#    'diesel': '3.675'},
#   {'currency': 'usd',
#    'name': 'Vermont',
#    'gasoline': '3.092',
#    'midGrade': '3.671',
#    'premium': '4.064',
#    'diesel': '3.833'},
#   {'currency': 'usd',
#    'name': 'Washington',
#    'gasoline': '4.389',
#    'midGrade': '4.652',
#    'premium': '4.891',
#    'diesel': '5.063'},
#   {'currency': 'usd',
#    'name': 'Wisconsin',
#    'gasoline': '2.932',
#    'midGrade': '3.450',
#    'premium': '3.964',
#    'diesel': '3.537'},
#   {'currency': 'usd',
#    'name': 'West Virginia',
#    'gasoline': '3.050',
#    'midGrade': '3.483',
#    'premium': '3.915',
#    'diesel': '3.607'},
#   {'currency': 'usd',
#    'name': 'Wyoming',
#    'gasoline': '3.110',
#    'midGrade': '3.405',
#    'premium': '3.673',
#    'diesel': '3.635'}]}

# %%
results = converted_data["result"]
results
# Out:
# [{'currency': 'usd',
#   'name': 'Alaska',
#   'gasoline': '3.754',
#   'midGrade': '3.968',
#   'premium': '4.205',
#   'diesel': '4.062'},
#  {'currency': 'usd',
#   'name': 'Alabama',
#   'gasoline': '2.788',
#   'midGrade': '3.240',
#   'premium': '3.639',
#   'diesel': '3.481'},
#  {'currency': 'usd',
#   'name': 'Arkansas',
#   'gasoline': '2.787',
#   'midGrade': '3.237',
#   'premium': '3.609',
#   'diesel': '3.407'},
#  {'currency': 'usd',
#   'name': 'Arizona',
#   'gasoline': '3.202',
#   'midGrade': '3.557',
#   'premium': '3.879',
#   'diesel': '3.649'},
#  {'currency': 'usd',
#   'name': 'California',
#   'gasoline': '4.481',
#   'midGrade': '4.711',
#   'premium': '4.891',
#   'diesel': '5.179'},
#  {'currency': 'usd',
#   'name': 'Colorado',
#   'gasoline': '2.986',
#   'midGrade': '3.376',
#   'premium': '3.700',
#   'diesel': '3.500'},
#  {'currency': 'usd',
#   'name': 'Connecticut',
#   'gasoline': '3.107',
#   'midGrade': '3.700',
#   'premium': '4.066',
#   'diesel': '3.794'},
#  {'currency': 'usd',
#   'name': 'District of Columbia',
#   'gasoline': '3.329',
#   'midGrade': '3.815',
#   'premium': '4.252',
#   'diesel': '3.848'},
#  {'currency': 'usd',
#   'name': 'Delaware',
#   'gasoline': '3.099',
#   'midGrade': '3.669',
#   'premium': '3.958',
#   'diesel': '3.763'},
#  {'currency': 'usd',
#   'name': 'Florida',
#   'gasoline': '3.005',
#   'midGrade': '3.455',
#   'premium': '3.773',
#   'diesel': '3.623'},
#  {'currency': 'usd',
#   'name': 'Georgia',
#   'gasoline': '2.921',
#   'midGrade': '3.392',
#   'premium': '3.794',
#   'diesel': '3.606'},
#  {'currency': 'usd',
#   'name': 'Hawaii',
#   'gasoline': '4.475',
#   'midGrade': '4.701',
#   'premium': '4.963',
#   'diesel': '5.230'},
#  {'currency': 'usd',
#   'name': 'Iowa',
#   'gasoline': '2.999',
#   'midGrade': '3.205',
#   'premium': '3.780',
#   'diesel': '3.570'},
#  {'currency': 'usd',
#   'name': 'Idaho',
#   'gasoline': '3.483',
#   'midGrade': '3.767',
#   'premium': '4.040',
#   'diesel': '3.963'},
#  {'currency': 'usd',
#   'name': 'Illinois',
#   'gasoline': '3.443',
#   'midGrade': '4.036',
#   'premium': '4.494',
#   'diesel': '3.785'},
#  {'currency': 'usd',
#   'name': 'Indiana',
#   'gasoline': '3.253',
#   'midGrade': '3.782',
#   'premium': '4.275',
#   'diesel': '3.860'},
#  {'currency': 'usd',
#   'name': 'Kansas',
#   'gasoline': '2.851',
#   'midGrade': '3.182',
#   'premium': '3.526',
#   'diesel': '3.482'},
#  {'currency': 'usd',
#   'name': 'Kentucky',
#   'gasoline': '2.869',
#   'midGrade': '3.418',
#   'premium': '3.835',
#   'diesel': '3.462'},
#  {'currency': 'usd',
#   'name': 'Louisiana',
#   'gasoline': '2.777',
#   'midGrade': '3.225',
#   'premium': '3.597',
#   'diesel': '3.371'},
#  {'currency': 'usd',
#   'name': 'Massachusetts',
#   'gasoline': '3.044',
#   'midGrade': '3.664',
#   'premium': '4.030',
#   'diesel': '3.847'},
#  {'currency': 'usd',
#   'name': 'Maryland',
#   'gasoline': '3.106',
#   'midGrade': '3.696',
#   'premium': '4.000',
#   'diesel': '3.786'},
#  {'currency': 'usd',
#   'name': 'Maine',
#   'gasoline': '3.095',
#   'midGrade': '3.655',
#   'premium': '4.108',
#   'diesel': '3.893'},
#  {'currency': 'usd',
#   'name': 'Michigan',
#   'gasoline': '3.161',
#   'midGrade': '3.727',
#   'premium': '4.279',
#   'diesel': '3.732'},
#  {'currency': 'usd',
#   'name': 'Minnesota',
#   'gasoline': '3.026',
#   'midGrade': '3.446',
#   'premium': '3.880',
#   'diesel': '3.624'},
#  {'currency': 'usd',
#   'name': 'Missouri',
#   'gasoline': '2.846',
#   'midGrade': '3.209',
#   'premium': '3.529',
#   'diesel': '3.475'},
#  {'currency': 'usd',
#   'name': 'Mississippi',
#   'gasoline': '2.711',
#   'midGrade': '3.168',
#   'premium': '3.527',
#   'diesel': '3.315'},
#  {'currency': 'usd',
#   'name': 'Montana',
#   'gasoline': '3.246',
#   'midGrade': '3.556',
#   'premium': '3.893',
#   'diesel': '3.650'},
#  {'currency': 'usd',
#   'name': 'North Carolina',
#   'gasoline': '2.900',
#   'midGrade': '3.360',
#   'premium': '3.743',
#   'diesel': '3.536'},
#  {'currency': 'usd',
#   'name': 'North Dakota',
#   'gasoline': '2.911',
#   'midGrade': '3.250',
#   'premium': '3.589',
#   'diesel': '3.436'},
#  {'currency': 'usd',
#   'name': 'Nebraska',
#   'gasoline': '2.951',
#   'midGrade': '3.158',
#   'premium': '3.651',
#   'diesel': '3.444'},
#  {'currency': 'usd',
#   'name': 'New Hampshire',
#   'gasoline': '2.994',
#   'midGrade': '3.578',
#   'premium': '3.994',
#   'diesel': '3.812'},
#  {'currency': 'usd',
#   'name': 'New Jersey',
#   'gasoline': '3.063',
#   'midGrade': '3.627',
#   'premium': '3.883',
#   'diesel': '3.717'},
#  {'currency': 'usd',
#   'name': 'New Mexico',
#   'gasoline': '2.916',
#   'midGrade': '3.324',
#   'premium': '3.601',
#   'diesel': '3.542'},
#  {'currency': 'usd',
#   'name': 'Nevada',
#   'gasoline': '3.736',
#   'midGrade': '4.040',
#   'premium': '4.309',
#   'diesel': '3.973'},
#  {'currency': 'usd',
#   'name': 'New York',
#   'gasoline': '3.167',
#   'midGrade': '3.690',
#   'premium': '4.066',
#   'diesel': '3.921'},
#  {'currency': 'usd',
#   'name': 'Ohio',
#   'gasoline': '2.988',
#   'midGrade': '3.526',
#   'premium': '4.038',
#   'diesel': '3.669'},
#  {'currency': 'usd',
#   'name': 'Oklahoma',
#   'gasoline': '2.778',
#   'midGrade': '3.171',
#   'premium': '3.461',
#   'diesel': '3.343'},
#  {'currency': 'usd',
#   'name': 'Oregon',
#   'gasoline': '3.975',
#   'midGrade': '4.200',
#   'premium': '4.468',
#   'diesel': '4.502'},
#  {'currency': 'usd',
#   'name': 'Pennsylvania',
#   'gasoline': '3.236',
#   'midGrade': '3.685',
#   'premium': '4.049',
#   'diesel': '4.021'},
#  {'currency': 'usd',
#   'name': 'Rhode Island',
#   'gasoline': '3.021',
#   'midGrade': '3.753',
#   'premium': '4.150',
#   'diesel': '3.821'},
#  {'currency': 'usd',
#   'name': 'South Carolina',
#   'gasoline': '2.832',
#   'midGrade': '3.296',
#   'premium': '3.667',
#   'diesel': '3.494'},
#  {'currency': 'usd',
#   'name': 'South Dakota',
#   'gasoline': '3.033',
#   'midGrade': '3.189',
#   'premium': '3.673',
#   'diesel': '3.381'},
#  {'currency': 'usd',
#   'name': 'Tennessee',
#   'gasoline': '2.763',
#   'midGrade': '3.229',
#   'premium': '3.625',
#   'diesel': '3.455'},
#  {'currency': 'usd',
#   'name': 'Texas',
#   'gasoline': '2.779',
#   'midGrade': '3.257',
#   'premium': '3.609',
#   'diesel': '3.295'},
#  {'currency': 'usd',
#   'name': 'Utah',
#   'gasoline': '3.383',
#   'midGrade': '3.651',
#   'premium': '3.884',
#   'diesel': '3.737'},
#  {'currency': 'usd',
#   'name': 'Virginia',
#   'gasoline': '3.024',
#   'midGrade': '3.516',
#   'premium': '3.883',
#   'diesel': '3.675'},
#  {'currency': 'usd',
#   'name': 'Vermont',
#   'gasoline': '3.092',
#   'midGrade': '3.671',
#   'premium': '4.064',
#   'diesel': '3.833'},
#  {'currency': 'usd',
#   'name': 'Washington',
#   'gasoline': '4.389',
#   'midGrade': '4.652',
#   'premium': '4.891',
#   'diesel': '5.063'},
#  {'currency': 'usd',
#   'name': 'Wisconsin',
#   'gasoline': '2.932',
#   'midGrade': '3.450',
#   'premium': '3.964',
#   'diesel': '3.537'},
#  {'currency': 'usd',
#   'name': 'West Virginia',
#   'gasoline': '3.050',
#   'midGrade': '3.483',
#   'premium': '3.915',
#   'diesel': '3.607'},
#  {'currency': 'usd',
#   'name': 'Wyoming',
#   'gasoline': '3.110',
#   'midGrade': '3.405',
#   'premium': '3.673',
#   'diesel': '3.635'}]

# %%
#creating a dataframe
df = pd.DataFrame(results)
df.shape
# Out:
# (51, 6)

# %%
df.head()
# Out:
#   currency        name gasoline midGrade premium diesel
# 0      usd      Alaska    3.754    3.968   4.205  4.062
# 1      usd     Alabama    2.788    3.240   3.639  3.481
# 2      usd    Arkansas    2.787    3.237   3.609  3.407
# 3      usd     Arizona    3.202    3.557   3.879  3.649
# 4      usd  California    4.481    4.711   4.891  5.179

# %%
import http.client

conn = http.client.HTTPSConnection("api.collectapi.com")

headers = {
    'content-type': "application/json",
    'authorization': "apikey 58mZ1nq40hESqQKgspMMGG:1TVmfC219hl24aPkk6ntlv"
    }

conn.request("GET", "/gasPrice/stateUsaPrice?state=WA", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
