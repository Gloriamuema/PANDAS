# %%
import pandas as pd
from sqlalchemy import create_engine

df = pd.read_csv("mock_data.csv")
df.head()
# Out:
#    id first_name  last_name                        email  gender  \
# 0   1     Menard   D'Andrea      mdandrea0@posterous.com    Male
# 1   2   Alistair   Kovalski     akovalski1@google.com.hk    Male
# 2   3     Padget  Vallerine  pvallerine2@theguardian.com    Male
# 3   4  Marcellus  Adolphine           madolphine3@goo.gl    Male
# 4   5       Aila     Lokier             alokier4@fc2.com  Female
#
#         ip_address
# 0  186.148.148.137
# 1   139.25.249.243
# 2    71.254.23.223
# 3    241.177.223.0
# 4      93.2.84.241

# %%
df.tail( n=2)
# Out:
#        id first_name    last_name                     email    gender  \
# 998   999    Christa        Dorre  cdorrerq@dailymotion.com  Bigender
# 999  1000     Britni  Giovannilli   bgiovannillirr@furl.net    Female
#
#         ip_address
# 998  87.151.141.44
# 999  53.69.165.198

# %%
df.describe()
# Out:
#                 id
# count  1000.000000
# mean    500.500000
# std     288.819436
# min       1.000000
# 25%     250.750000
# 50%     500.500000
# 75%     750.250000
# max    1000.000000

# %%
#The .info() method is a quick way to look at the data types, missing values, and data size of a DataFrame.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   ip_address  1000 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB

# %%
#getting all columns and column names

df.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address'], dtype='object')

# %%
#checking missing values
df.isnull
# Out:
# <bound method DataFrame.isnull of        id first_name    last_name                        email    gender  \
# 0       1     Menard     D'Andrea      mdandrea0@posterous.com      Male
# 1       2   Alistair     Kovalski     akovalski1@google.com.hk      Male
# 2       3     Padget    Vallerine  pvallerine2@theguardian.com      Male
# 3       4  Marcellus    Adolphine           madolphine3@goo.gl      Male
# 4       5       Aila       Lokier             alokier4@fc2.com    Female
# ..    ...        ...          ...                          ...       ...
# 995   996     Stepha      Keasley           skeasleyrn@mac.com    Female
# 996   997      Clara        Caneo       ccaneoro@indiegogo.com    Female
# 997   998   Ealasaid       Tayloe          etayloerp@google.cn    Female
# 998   999    Christa        Dorre     cdorrerq@dailymotion.com  Bigender
# 999  1000     Britni  Giovannilli      bgiovannillirr@furl.net    Female
#
#           ip_address
# 0    186.148.148.137
# ...

# %%
df.head()
# Out:
#    id first_name  last_name                        email  gender  \
# 0   1     Menard   D'Andrea      mdandrea0@posterous.com    Male
# 1   2   Alistair   Kovalski     akovalski1@google.com.hk    Male
# 2   3     Padget  Vallerine  pvallerine2@theguardian.com    Male
# 3   4  Marcellus  Adolphine           madolphine3@goo.gl    Male
# 4   5       Aila     Lokier             alokier4@fc2.com  Female
#
#         ip_address
# 0  186.148.148.137
# 1   139.25.249.243
# 2    71.254.23.223
# 3    241.177.223.0
# 4      93.2.84.241

# %%
#sorting values by column name
df.sort_values(by="first_name")
# Out:
#       id first_name last_name                       email      gender  \
# 370  371    Abagael    Yurkov        ayurkovaa@apache.org      Female
# 282  283    Abagail     Jenik            ajenik7u@mit.edu      Female
# 772  773         Ad    Helder          ahelderlg@uiuc.edu        Male
# 967  968   Adelaide   Fibbens     afibbensqv@redcross.org  Polygender
# 65    66     Adella      Wyre            awyre1t@hibu.com  Non-binary
# ..   ...        ...       ...                         ...         ...
# 606  607       Zane  Levesque        zlevesquegu@xing.com        Male
# 792  793      Zarah     Suart            zsuartm0@163.com      Female
# 304  305        Zeb    Carsey  zcarsey8g@businessweek.com        Male
# 71    72      Zonda   Creavin          zcreavin1z@ibm.com      Female
# 577  578       Zora   Frankel     zfrankelg1@japanpost.jp      Female
#
#          ip_address
# 370   47.142.55.153
# 282  54.107.250.227
# 772   34.153.145.80
# 967   8.173.172.132
# ...

# %%
#sorting values by multiple columns
df.sort_values(by=["first_name","last_name"])
# Out:
#       id first_name last_name                       email      gender  \
# 370  371    Abagael    Yurkov        ayurkovaa@apache.org      Female
# 282  283    Abagail     Jenik            ajenik7u@mit.edu      Female
# 772  773         Ad    Helder          ahelderlg@uiuc.edu        Male
# 967  968   Adelaide   Fibbens     afibbensqv@redcross.org  Polygender
# 65    66     Adella      Wyre            awyre1t@hibu.com  Non-binary
# ..   ...        ...       ...                         ...         ...
# 606  607       Zane  Levesque        zlevesquegu@xing.com        Male
# 792  793      Zarah     Suart            zsuartm0@163.com      Female
# 304  305        Zeb    Carsey  zcarsey8g@businessweek.com        Male
# 71    72      Zonda   Creavin          zcreavin1z@ibm.com      Female
# 577  578       Zora   Frankel     zfrankelg1@japanpost.jp      Female
#
#          ip_address
# 370   47.142.55.153
# 282  54.107.250.227
# 772   34.153.145.80
# 967   8.173.172.132
# ...

# %%
df.head()
# Out:
#    id first_name  last_name                        email  gender  \
# 0   1     Menard   D'Andrea      mdandrea0@posterous.com    Male
# 1   2   Alistair   Kovalski     akovalski1@google.com.hk    Male
# 2   3     Padget  Vallerine  pvallerine2@theguardian.com    Male
# 3   4  Marcellus  Adolphine           madolphine3@goo.gl    Male
# 4   5       Aila     Lokier             alokier4@fc2.com  Female
#
#         ip_address
# 0  186.148.148.137
# 1   139.25.249.243
# 2    71.254.23.223
# 3    241.177.223.0
# 4      93.2.84.241

# %%
#filtering the data
df[df["id"] > 300]
# Out:
#        id first_name    last_name                         email    gender  \
# 300   301   Angelika      Dowdney        adowdney8c@plala.or.jp    Female
# 301   302       Noel    MacMenemy  nmacmenemy8d@bizjournals.com    Female
# 302   303      Vance      Battson           vbattson8e@about.me      Male
# 303   304  Marie-ann        Balam           mbalam8f@taobao.com    Female
# 304   305        Zeb       Carsey    zcarsey8g@businessweek.com      Male
# ..    ...        ...          ...                           ...       ...
# 995   996     Stepha      Keasley            skeasleyrn@mac.com    Female
# 996   997      Clara        Caneo        ccaneoro@indiegogo.com    Female
# 997   998   Ealasaid       Tayloe           etayloerp@google.cn    Female
# 998   999    Christa        Dorre      cdorrerq@dailymotion.com  Bigender
# 999  1000     Britni  Giovannilli       bgiovannillirr@furl.net    Female
#
#          ip_address
# 300    28.56.35.112
# 301   27.213.192.13
# ...

# %%
#isolating one column using []
df["first_name"]
# Out:
# 0         Menard
# 1       Alistair
# 2         Padget
# 3      Marcellus
# 4           Aila
#          ...
# 995       Stepha
# 996        Clara
# 997     Ealasaid
# 998      Christa
# 999       Britni
# Name: first_name, Length: 1000, dtype: object

# %%
#isolating two columns using [[]]
df[["first_name","last_name"]]
# Out:
#     first_name    last_name
# 0       Menard     D'Andrea
# 1     Alistair     Kovalski
# 2       Padget    Vallerine
# 3    Marcellus    Adolphine
# 4         Aila       Lokier
# ..         ...          ...
# 995     Stepha      Keasley
# 996      Clara        Caneo
# 997   Ealasaid       Tayloe
# 998    Christa        Dorre
# 999     Britni  Giovannilli
#
# [1000 rows x 2 columns]

# %%
#database connect details
db_user = 'postgres'
db_password ='test123'
db_host ='localhost'
db_port = '5432'
db_name = 'postgres'
table_name ='mock_data'

# Create engine with f-string
engine = create_engine(f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}')
 
# Insert data with interpolated table name
df.to_sql('mock_data', con=engine, if_exists='append', index=False)
# Out:
# 1000

# %%
import sys
# !{sys.executable} -m pip install psycopg2-binary
# Out:
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.2 MB ? eta -:--:--
#    ------------------ --------------------- 0.5/1.2 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------ --- 1.0/1.2 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 1.8 MB/s eta 0:00:00
# ...

# %%
import psycopg2
print("psycopg2 is working!")
# Out:
# psycopg2 is working!

# %%
df.head()
# Out:
#    id first_name  last_name                        email  gender  \
# 0   1     Menard   D'Andrea      mdandrea0@posterous.com    Male
# 1   2   Alistair   Kovalski     akovalski1@google.com.hk    Male
# 2   3     Padget  Vallerine  pvallerine2@theguardian.com    Male
# 3   4  Marcellus  Adolphine           madolphine3@goo.gl    Male
# 4   5       Aila     Lokier             alokier4@fc2.com  Female
#
#         ip_address
# 0  186.148.148.137
# 1   139.25.249.243
# 2    71.254.23.223
# 3    241.177.223.0
# 4      93.2.84.241

# %%
df['id'].plot.line()
# Out:
# <Axes: >
